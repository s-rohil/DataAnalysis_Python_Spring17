# %%
import pandas as pd
import os
import datetime
import numpy as np
# Out:
# /Users/kvs25/anaconda3/lib/python3.5/site-packages/numexpr/cpuinfo.py:53: UserWarning: [Errno 2] No such file or directory: 'machine'
#   stacklevel=stacklevel + 1)
# /Users/kvs25/anaconda3/lib/python3.5/site-packages/numexpr/cpuinfo.py:53: UserWarning: [Errno 2] No such file or directory: 'arch'
#   stacklevel=stacklevel + 1)
# /Users/kvs25/anaconda3/lib/python3.5/site-packages/numexpr/cpuinfo.py:76: UserWarning: [Errno 2] No such file or directory: 'sysctl'
#   stacklevel=stacklevel + 1):

# %%
df = pd.read_csv('employee_compensation.csv')

# %%
df.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
#
#                           Department  Union Code  \
# 0                 Airport Commission        38.0
# 1                      Public Health       790.0
# 2  Department of the Status of Women       323.0
# 3                    Human Resources       790.0
# 4     Recreation and Park Commission       790.0
#
#                                 Union Job Family Code           Job Family  \
# 0  Plumbers and Pipefitters, Local 38            7300     Journeyman Trade
# 1    SEIU - Miscellaneous, Local 1021            2600       Dietary & Food
# 2   Members of Boards and Commissions            0900           Management
# 3    SEIU - Miscellaneous, Local 1021            8100        Legal & Court
# 4    SEIU - Miscellaneous, Local 1021            9900  Public Service Aide
#
#           ...         Employee Identifier  Salaries  Overtime  Other Salaries  \
# 0         ...                       52206  98528.52      0.00         3955.59
# 1         ...                       52950  69169.82    755.02         4179.08
# 2         ...                       33958    200.00      0.00            0.00
# 3         ...                       33073   1783.00      0.00            0.00
# 4         ...                       15849   1102.50      0.00            0.00
#
#    Total Salary  Retirement  Health/Dental  Other Benefits  Total Benefits  \
# 0     102484.11    20142.55       12918.24         8371.76        41432.55
# 1      74103.92    15641.92       12499.30         5669.02        33810.24
# 2        200.00        0.00          51.45           15.83           67.28
# 3       1783.00      325.05         257.23          153.85          736.13
# 4       1102.50        0.00         538.82           85.36          624.18
#
#    Total Compensation
# 0           143916.66
# 1           107914.16
# 2              267.28
# 3             2519.13
# 4             1726.68
#
# [5 rows x 22 columns]

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
data = df.groupby(['Organization_Group','Department'], as_index=False)['Total_Compensation'].mean()

# %%
data.head(10)
# Out:
#                  Organization_Group                      Department  \
# 0                  Community Health                   Public Health
# 1              Culture & Recreation             Academy of Sciences
# 2              Culture & Recreation                 Arts Commission
# 3              Culture & Recreation                Asian Art Museum
# 4              Culture & Recreation                Fine Arts Museum
# 5              Culture & Recreation                     Law Library
# 6              Culture & Recreation                  Public Library
# 7              Culture & Recreation  Recreation and Park Commission
# 8              Culture & Recreation                    War Memorial
# 9  General Administration & Finance               Assessor/Recorder
#
#    Total_Compensation
# 0        96190.190140
# 1       107319.727692
# 2        94339.597388
# 3        71401.520060
# 4        44205.439895
# 5       188424.362222
# 6        70446.352147
# 7        38912.859465
# 8        76250.068022
# 9        89994.260614

# %%
new_data=data.sort_values(by=['Organization_Group','Total_Compensation'],ascending=[True,False])
#new_data.head(10)

# %%
new_data.head(10)
# Out:
#                   Organization_Group                      Department  \
# 0                   Community Health                   Public Health
# 5               Culture & Recreation                     Law Library
# 1               Culture & Recreation             Academy of Sciences
# 2               Culture & Recreation                 Arts Commission
# 8               Culture & Recreation                    War Memorial
# 3               Culture & Recreation                Asian Art Museum
# 6               Culture & Recreation                  Public Library
# 4               Culture & Recreation                Fine Arts Museum
# 7               Culture & Recreation  Recreation and Park Commission
# 11  General Administration & Finance                   City Attorney
#
#     Total_Compensation
# 0         96190.190140
# 5        188424.362222
# 1        107319.727692
# 2         94339.597388
# 8         76250.068022
# 3         71401.520060
# 6         70446.352147
# 4         44205.439895
# 7         38912.859465
# 11       166082.677561

# %%
#test=df.groupby(['Organization_Group','Department']).agg({'Total_Compensation':np.mean})

# %%
new_data.to_csv(path_or_buf=os.path.join(os.getcwd(),'Q2P1.csv'))

# %%
# printing the top Department of each Organization Group with the highest compensation
best_dept=new_data.sort_values('Total_Compensation', ascending=False).groupby('Organization_Group', as_index=False).first()

# %%
best_dept.head(7)
# Out:
#                          Organization_Group                Department  \
# 0                          Community Health             Public Health
# 1                      Culture & Recreation               Law Library
# 2          General Administration & Finance             City Attorney
# 3             General City Responsibilities  General Fund Unallocated
# 4  Human Welfare & Neighborhood Development    Rent Arbitration Board
# 5                         Public Protection           Fire Department
# 6   Public Works, Transportation & Commerce                      Port
#
#    Total_Compensation
# 0        96190.190140
# 1       188424.362222
# 2       166082.677561
# 3        15824.151304
# 4       102181.793941
# 5       180788.086979
# 6       112139.680017
