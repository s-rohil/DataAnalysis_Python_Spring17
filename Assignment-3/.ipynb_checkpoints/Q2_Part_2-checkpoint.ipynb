# %%
import pandas as pd
import os
import datetime
import numpy as np
import calendar
# Out:
# /Users/kvs25/anaconda3/lib/python3.5/site-packages/numexpr/cpuinfo.py:53: UserWarning: [Errno 2] No such file or directory: 'arch'
#   stacklevel=stacklevel + 1)
# /Users/kvs25/anaconda3/lib/python3.5/site-packages/numexpr/cpuinfo.py:53: UserWarning: [Errno 2] No such file or directory: 'machine'
#   stacklevel=stacklevel + 1)
# /Users/kvs25/anaconda3/lib/python3.5/site-packages/numexpr/cpuinfo.py:76: UserWarning: [Errno 2] No such file or directory: 'sysctl'
#   stacklevel=stacklevel + 1):

# %%
df = pd.read_csv('employee_compensation.csv')

# %%
df.head(15)
# Out:
#    Year Type  Year  Organization Group Code  \
# 0   Calendar  2013                        2
# 1     Fiscal  2015                        4
# 2   Calendar  2016                        3
# 3   Calendar  2016                        6
# 4     Fiscal  2015                        5
# 5   Calendar  2016                        2
# 6     Fiscal  2013                        2
# 7   Calendar  2014                        6
# 8   Calendar  2015                        2
# 9     Fiscal  2014                        2
# 10  Calendar  2016                        4
# 11    Fiscal  2015                        4
# 12    Fiscal  2014                        5
# 13  Calendar  2013                        2
# 14  Calendar  2014                        5
#
#                           Organization Group Department Code  \
# 0    Public Works, Transportation & Commerce             AIR
# 1                           Community Health             DPH
# 2   Human Welfare & Neighborhood Development             WOM
# 3           General Administration & Finance             HRD
# 4                       Culture & Recreation             REC
# 5    Public Works, Transportation & Commerce             DBI
# 6    Public Works, Transportation & Commerce             DPW
# 7           General Administration & Finance             ADM
# 8    Public Works, Transportation & Commerce             AIR
# 9    Public Works, Transportation & Commerce             AIR
# 10                          Community Health             DPH
# 11                          Community Health             DPH
# 12                      Culture & Recreation             REC
# 13   Public Works, Transportation & Commerce             DPW
# 14                      Culture & Recreation             REC
#
#                                 Department  Union Code  \
# 0                       Airport Commission        38.0
# 1                            Public Health       790.0
# 2        Department of the Status of Women       323.0
# 3                          Human Resources       790.0
# 4           Recreation and Park Commission       790.0
# 5        Department of Building Inspection       790.0
# 6   General Services Agency - Public Works        21.0
# 7     General Services Agency - City Admin       790.0
# 8                       Airport Commission       790.0
# 9                       Airport Commission       790.0
# 10                           Public Health       250.0
# 11                           Public Health       250.0
# 12          Recreation and Park Commission       790.0
# 13  General Services Agency - Public Works        38.0
# 14          Recreation and Park Commission       261.0
#
#                                               Union Job Family Code  \
# 0                Plumbers and Pipefitters, Local 38            7300
# 1                  SEIU - Miscellaneous, Local 1021            2600
# 2                 Members of Boards and Commissions            0900
# 3                  SEIU - Miscellaneous, Local 1021            8100
# 4                  SEIU - Miscellaneous, Local 1021            9900
# 5                  SEIU - Miscellaneous, Local 1021            1400
# 13         717.70          439.52         2367.57             8044.63
# 14       13054.95         6721.63        34064.57           117266.41
#
# [15 rows x 22 columns]

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
dataset=df.groupby(['Year','Employee_Identifier']).agg({'Total_Salary':np.mean, 'Retirement':np.mean,'Health/Dental':np.mean,'Other_Benefits':np.mean,'Total_Benefits':np.mean,'Total_Compensation':np.mean})

# %%
dataset.head(6)
# Out:
#                           Health/Dental  Retirement  Total_Compensation  \
# Year Employee_Identifier
# 2013 1                        12788.245   10669.540           84271.090
#      3                         5743.665    4856.690           41103.010
#      4                         1004.750       0.000            5217.670
#      5                            0.000       0.000           22377.795
#      6                        15689.105   27433.560          218912.525
#      7                         8904.645   29400.355          235769.200
#
#                           Total_Salary  Other_Benefits  Total_Benefits
# Year Employee_Identifier
# 2013 1                       56300.410        4512.895       27970.680
#      3                       28213.960        2288.695       12889.050
#      4                        3910.200         302.720        1307.470
#      5                       20739.375        1638.420        1638.420
#      6                      172972.350        2817.510       45940.175
#      7                      187017.435       10446.765       48751.765

# %%
df[df.Overtime>0.05*(df.Salaries)].Employee_Identifier.head()
# Out:
# 11    10006
# 14    23029
# 23    20763
# 28    49815
# 31    43372
# Name: Employee_Identifier, dtype: int64

# %%
output=df.groupby('Job_Family').agg({'Total_Benefits':np.mean, 'Total_Compensation':np.mean})

# %%
output.head()
# Out:
#                                Total_Compensation  Total_Benefits
# Job_Family
# Administrative & Mgmt (Unrep)       248536.124310    58804.222241
# Administrative Secretarial          101995.198101    28918.649873
# Administrative-DPW/PUC              156364.681576    41349.404069
# Administrative-Labor & Trades       160870.450896    39922.411887
# Agriculture & Horticulture           81391.643272    25407.737041

# %%
output['percentage']=(output.Total_Benefits/output.Total_Compensation)*100

# %%
output.head()
# Out:
#                                Total_Compensation  Total_Benefits  percentage
# Job_Family
# Administrative & Mgmt (Unrep)       248536.124310    58804.222241   23.660231
# Administrative Secretarial          101995.198101    28918.649873   28.352952
# Administrative-DPW/PUC              156364.681576    41349.404069   26.444210
# Administrative-Labor & Trades       160870.450896    39922.411887   24.816498
# Agriculture & Horticulture           81391.643272    25407.737041   31.216641

# %%
output.sort_values(by='percentage',ascending=False).head(5)
# Out:
#                                Total_Compensation  Total_Benefits  percentage
# Job_Family
# Public Service Aide                  14450.325272     5087.142130   35.204343
# Housekeeping & Laundry               72612.204294    23787.827171   32.760095
# Park & Zoo                           53001.043501    17359.449541   32.753034
# Clerical, Secretarial & Steno        66009.821043    21394.905197   32.411700
# Dietary & Food                       60295.256688    19300.787905   32.010458

# %%
output.to_csv(path_or_buf=os.path.join(os.getcwd(),'Q2P2.csv'))
